# %% [markdown]
# ## This dataset contains complete information about various aspects of crimes happened in India from 2001 to 2012. <br>There are many factors that can be analysed from this dataset.<br>Over all, I hope this dataset helps us to understand better about India.

# %%
#Libraries to be used
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('classic')

# %%
df=pd.read_csv('india-crime.csv')

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
#Generic Info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9017 non-null   object
#  1   DISTRICT                                             9017 non-null   object
#  2   Year                                                 9017 non-null   int64
#  3   Rape                                                 9017 non-null   int64
#  4   Kidnapping and Abduction                             9017 non-null   int64
#  5   Dowry Deaths                                         9017 non-null   int64
#  6   Assault on women with intent to outrage her modesty  9017 non-null   int64
#  7   Insult to modesty of Women                           9017 non-null   int64
# ...

# %%
# Checking null values
df.isnull().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping and Abduction                               0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
#Dropping any duplicate row
df.drop_duplicates(inplace=True)

#No duplicate row found

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
# Data we have for the years
years=df["Year"].unique().tolist()
years.insert(0,'Overall')
years
# Out:
# ['Overall',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012']

# %%
# Number of districts in data
districts=df["DISTRICT"].unique().tolist()
districts
# Out:
# ['ADILABAD',
#  'ANANTAPUR',
#  'CHITTOOR',
#  'CUDDAPAH',
#  'EAST GODAVARI',
#  'GUNTAKAL RLY.',
#  'GUNTUR',
#  'HYDERABAD CITY',
#  'KARIMNAGAR',
#  'KHAMMAM',
#  'KRISHNA',
#  'KURNOOL',
#  'MAHABOOBNAGAR',
#  'MEDAK',
#  'NALGONDA',
#  'NELLORE',
#  'NIZAMABAD',
#  'PRAKASHAM',
#  'RANGA REDDY',
#  'SECUNDERABAD RLY.',
#  'SRIKAKULAM',
#  'VIJAYAWADA',
#  'VIJAYAWADA RLY.',
#  'VISAKHA RURAL',
#  'VISAKHAPATNAM',
#  'VIZIANAGARAM',
#  'WARANGAL',
#  'WEST GODAVARI',
#  'TOTAL',
#  'CHANGLANG',
#  'DIBANG VALLEY',
#  'KAMENG EAST',
#  'KAMENG WEST',
#  'LOHIT',
#  'PAPUM PARE',
#  'SIANG EAST',
#  'SIANG UPPER',
#  'SIANG WEST',
#  'SUBANSIRI LOWER',
#  'SUBANSIRI UPPER',
#  'TAWANG',
#  'TIRAP',
#  'BARPETA',
#  'BONGAIGAON',
#  'C.I.D.',
#  'CACHAR',
#  'DARRANG',
#  'DHEMAJI',
#  'DHUBRI',
#  'DIBRUGARH',
#  'G.R.P.',
#  'GOALPARA',
#  'GOLAGHAT',
#  'GUWAHATI CITY',
#  'HAILAKANDI',
#  'JORHAT',
#  'KAMRUP',
#  'KARBI ANGLONG',
#  'KARIMGANJ',
#  'KOKRAJHAR',
# ...

# %%
states=df["STATE/UT"].unique().tolist()
states.sort()
states.insert(0,'Overall')
states
# Out:
# ['Overall',
#  'A & N ISLANDS',
#  'ANDHRA PRADESH',
#  'ARUNACHAL PRADESH',
#  'ASSAM',
#  'BIHAR',
#  'CHANDIGARH',
#  'CHHATTISGARH',
#  'D & N HAVELI',
#  'DAMAN & DIU',
#  'DELHI',
#  'GOA',
#  'GUJARAT',
#  'HARYANA',
#  'HIMACHAL PRADESH',
#  'JAMMU & KASHMIR',
#  'JHARKHAND',
#  'KARNATAKA',
#  'KERALA',
#  'LAKSHADWEEP',
#  'MADHYA PRADESH',
#  'MAHARASHTRA',
#  'MANIPUR',
#  'MEGHALAYA',
#  'MIZORAM',
#  'NAGALAND',
#  'ODISHA',
#  'PUDUCHERRY',
#  'PUNJAB',
#  'RAJASTHAN',
#  'SIKKIM',
#  'TAMIL NADU',
#  'TRIPURA',
#  'UTTAR PRADESH',
#  'UTTARAKHAND',
#  'WEST BENGAL']

# %%
df['Year']=df['Year'].astype(str)

# %% [markdown]
# # State/UT wise

# %%
data=df[(df['DISTRICT']=="TOTAL")]
data
# Out:
#                STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 28       ANDHRA PRADESH    TOTAL  2001   871                       765
# 42    ARUNACHAL PRADESH    TOTAL  2001    33                        55
# 70                ASSAM    TOTAL  2001   817                      1070
# 115               BIHAR    TOTAL  2001   888                       518
# 135        CHHATTISGARH    TOTAL  2001   959                       171
# ...                 ...      ...   ...   ...                       ...
# 8988         CHANDIGARH    TOTAL  2012    27                        66
# 8990       D & N HAVELI    TOTAL  2012     3                         9
# 8993        DAMAN & DIU    TOTAL  2012     5                         0
# 9013        LAKSHADWEEP    TOTAL  2012     0                         0
# 9016         PUDUCHERRY    TOTAL  2012    13                        16
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
state_wise = df[df['DISTRICT'] == "TOTAL"].copy()
state_wise['Total_Cases'] = state_wise['Rape'] + state_wise['Kidnapping and Abduction'] + state_wise['Dowry Deaths'] + state_wise['Assault on women with intent to outrage her modesty'] + state_wise['Insult to modesty of Women'] + state_wise['Cruelty by Husband or his Relatives'] + state_wise['Importation of Girls']

state_wise.sort_values(by=['Year', 'STATE/UT'], inplace=True)
state_wise = state_wise.reset_index(drop=True)

state_wise
# Out:
#               STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0        A & N ISLANDS    TOTAL  2001     3                         2
# 1       ANDHRA PRADESH    TOTAL  2001   871                       765
# 2    ARUNACHAL PRADESH    TOTAL  2001    33                        55
# 3                ASSAM    TOTAL  2001   817                      1070
# 4                BIHAR    TOTAL  2001   888                       518
# ..                 ...      ...   ...   ...                       ...
# 403         TAMIL NADU    TOTAL  2012   737                      1693
# 404            TRIPURA    TOTAL  2012   229                       114
# 405      UTTAR PRADESH    TOTAL  2012  1963                      7910
# 406        UTTARAKHAND    TOTAL  2012   148                       256
# 407        WEST BENGAL    TOTAL  2012  2046                      4168
#
#      Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
state_grouped = state_wise.groupby(['STATE/UT']).sum()
state_grouped["STATE/UT"]=state_grouped.index
state_grouped
# Out:
#                     Year   Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# A & N ISLANDS      24078    109                        77             6
# ANDHRA PRADESH     24078  13479                     14936          6215
# ARUNACHAL PRADESH  24078    500                       558             2
# ASSAM              24078  16178                     22920          1276
# BIHAR              24078  13124                     19389         13548
# CHANDIGARH         24078    281                       534            42
# CHHATTISGARH       24078  11838                      2630          1142
# D & N HAVELI       24078     56                        94             1
# DAMAN & DIU        24078     20                        15             3
# GOA                24078    350                       164            19
# GUJARAT            24078   4249                     12918           502
# HARYANA            24078   6410                      6129          3130
# ...

# %%
plt.figure(figsize=(15,10))
ax=sns.barplot(y="Rape",x="STATE/UT",data=state_grouped)
ax.bar_label(ax.containers[0])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')
plt.title(f"Total Cases of each State during 2001 to 2012",fontsize=20)
plt.show()

# %%
state=input("Enter State name: ").upper()
if state in df["STATE/UT"].unique():
    state_wise=pd.DataFrame(df.loc[(df['DISTRICT']=="TOTAL") & (df["STATE/UT"]==state)].reset_index())
    state_wise.drop(['index'],axis=1,inplace=True)
    display(state_wise)
else:
    print("Check your input and provide a valid State/UT name")
# Out:
# Enter State name: assam
#    STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  Dowry Deaths  \
# 0     ASSAM    TOTAL  2001   817                      1070            59
# 1     ASSAM    TOTAL  2002   970                      1276            70
# 2     ASSAM    TOTAL  2003  1095                      1351            60
# 3     ASSAM    TOTAL  2004  1171                      1552            74
# 4     ASSAM    TOTAL  2005  1238                      1456            99
# 5     ASSAM    TOTAL  2006  1244                      1544           105
# 6     ASSAM    TOTAL  2007  1437                      1471           100
# 7     ASSAM    TOTAL  2008  1438                      1789           103
# 8     ASSAM    TOTAL  2009  1631                      2092           170
# 9     ASSAM    TOTAL  2010  1721                      2767           175
# 10    ASSAM    TOTAL  2011  1700                      3192           121
# ...

# %%
state_wise['Total_Cases']=state_wise['Rape']+state_wise['Kidnapping and Abduction']+state_wise['Dowry Deaths']+state_wise['Assault on women with intent to outrage her modesty']+state_wise['Insult to modesty of Women']+state_wise['Cruelty by Husband or his Relatives']+state_wise['Importation of Girls']
state_wise
# Out:
#    STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  Dowry Deaths  \
# 0     ASSAM    TOTAL  2001   817                      1070            59
# 1     ASSAM    TOTAL  2002   970                      1276            70
# 2     ASSAM    TOTAL  2003  1095                      1351            60
# 3     ASSAM    TOTAL  2004  1171                      1552            74
# 4     ASSAM    TOTAL  2005  1238                      1456            99
# 5     ASSAM    TOTAL  2006  1244                      1544           105
# 6     ASSAM    TOTAL  2007  1437                      1471           100
# 7     ASSAM    TOTAL  2008  1438                      1789           103
# 8     ASSAM    TOTAL  2009  1631                      2092           170
# 9     ASSAM    TOTAL  2010  1721                      2767           175
# 10    ASSAM    TOTAL  2011  1700                      3192           121
# 11    ASSAM    TOTAL  2012  1716                      3360           140
#
# ...

# %%
case=input("Enter the type of crime: ")
plt.figure(figsize=(15,10))
ax=sns.barplot(y=case,x="Year",data=state_wise)
ax.bar_label(ax.containers[0])
plt.title(f"{state.capitalize()} {case} Cases Per Year",fontsize=20)
plt.show()
# Out:
# Enter the type of crime: Rape

# %%
def fetch_state_list(df,case,state):
    state_df=df
    flag=0

    if case=='Overall' and state=='Overall':
        tmp_df=state_df
        return tmp_df
    elif case=='Overall' and state!='Overall':
        flag=1
        tmp_df=state_df[state_df["STATE/UT"]==state.upper()]
        tmp_df.reset_index(inplace=True,drop=True)
        return tmp_df
    elif case!='Overall' and state!='Overall':
        plt.figure(figsize=(15,10))
        ax=sns.barplot(y=case,x="Year",data=state_df)
        ax.bar_label(ax.containers[0])
        plt.title(f"{state.capitalize()} {case} Cases Per Year",fontsize=20)
        plt.show()
    elif case!='Overall' and state=='Overall':
        tmp_df=state_df[['STATE/UT','DISTRICT','Year',case]]
        tmp_df.reset_index(inplace=True,drop=True)
        return tmp_df

fetch_state_list(data,case='Rape',state='Assam')

# %%
tmp_df=state_wise
#display(tmp_df)
tmp_df=tmp_df.loc[(tmp_df["Year"]==2001)]
tmp_df.reset_index(drop=True)
tmp_df
# Out:
#              STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0       A & N ISLANDS    TOTAL  2001     3                         2
# 1      ANDHRA PRADESH    TOTAL  2001   871                       765
# 2   ARUNACHAL PRADESH    TOTAL  2001    33                        55
# 3               ASSAM    TOTAL  2001   817                      1070
# 4               BIHAR    TOTAL  2001   888                       518
# 5          CHANDIGARH    TOTAL  2001    18                        50
# 6        CHHATTISGARH    TOTAL  2001   959                       171
# 7        D & N HAVELI    TOTAL  2001     6                         2
# 8         DAMAN & DIU    TOTAL  2001     0                         3
# 9                 GOA    TOTAL  2001    12                         6
# 10            GUJARAT    TOTAL  2001   286                       857
# 11            HARYANA    TOTAL  2001   398                       297
# 12   HIMACHAL PRADESH    TOTAL  2001   124                       105
# ...

# %%
plt.figure(figsize=(15,10))
ax=sns.barplot(y="Total_Cases",x="STATE/UT",data=tmp_df)
ax.bar_label(ax.containers[0])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')
ax.set_xlabel("STATE/UT", size=15)
ax.set_ylabel("Total_Cases", size=15)
plt.title(f"Total Cases in each State during {yr}",fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       5 ax.set_xlabel("STATE/UT", size=15)
#       6 ax.set_ylabel("Total_Cases", size=15)
# ----> 7 plt.title(f"Total Cases in each State during {yr}",fontsize=20)
#
# NameError: name 'yr' is not defined

# %%
df
# Out:
#             STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2     ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
# ...              ...            ...   ...   ...                       ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012     0                         0
# 9013     LAKSHADWEEP          TOTAL  2012     0                         0
# 9014      PUDUCHERRY       KARAIKAL  2012     6                         2
# 9015      PUDUCHERRY     PUDUCHERRY  2012     7                        14
# 9016      PUDUCHERRY          TOTAL  2012    13                        16
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
# Collect the names of districts based on the State/UT name
state_ut = 'UTTAR PRADESH'  # Replace with the desired State/UT name
districts = df[df['STATE/UT'] == state_ut]['DISTRICT'].unique()
districts
# Print the names of districts
# Out:
# array(['AGRA', 'ALIGARH', 'ALLAHABAD', 'AMBEDKAR NAGAR', 'AURAIYA',
#        'AZAMGARH', 'BADAUN', 'BAGHPAT', 'BAHRAICH', 'BALLIA', 'BALRAMPUR',
#        'BANDA', 'BARABANKI', 'BAREILLY', 'BASTI', 'BIJNOR',
#        'BULANDSHAHAR', 'CHANDOLI', 'CHITRAKOOT DHAM', 'DEORIA', 'ETAH',
#        'ETAWAH', 'FAIZABAD', 'FATEHGARH', 'FATEHPUR', 'FIROZABAD',
#        'G.R.P.', 'GAUTAMBUDH NAGAR', 'GHAZIABAD', 'GHAZIPUR', 'GONDA',
#        'GORAKHPUR', 'HAMIRPUR', 'HARDOI', 'HATHRAS', 'J.P.NAGAR',
#        'JALAUN', 'JAUNPUR', 'JHANSI', 'KANNAUJ', 'KANPUR DEHAT',
#        'KANPUR NAGAR', 'KAUSHAMBI', 'KHIRI', 'KUSHI NAGAR', 'LALITPUR',
#        'LUCKNOW', 'MAHARAJGANJ', 'MAHOBA', 'MAINPURI', 'MATHURA', 'MAU',
#        'MEERUT', 'MIRZAPUR', 'MORADABAD', 'MUZAFFARNAGAR', 'PILIBHIT',
#        'PRATAPGARH', 'RAIBAREILLY', 'RAMPUR', 'SAHARANPUR',
#        'SANT KABIRNAGAR', 'SHAHJAHANPUR', 'SHRAWASTI', 'SIDHARTHNAGAR',
#        'SITAPUR', 'SONBHADRA', 'ST.RAVIDASNAGAR', 'SULTANPUR', 'UNNAO',
# ...

# %%
tmp=df[df["DISTRICT"]=="AGRA"]
tmp
# Out:
#            STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 579   UTTAR PRADESH     AGRA  2001    66                       132
# 1295  UTTAR PRADESH     AGRA  2002    41                       102
# 2024  UTTAR PRADESH     AGRA  2003    27                        73
# 2753  UTTAR PRADESH     AGRA  2004    32                       106
# 3486  UTTAR PRADESH     AGRA  2005    29                        77
# 4226  UTTAR PRADESH     AGRA  2006    26                       134
# 4969  UTTAR PRADESH     AGRA  2007    30                       149
# 5724  UTTAR PRADESH     AGRA  2008    42                       183
# 6491  UTTAR PRADESH     AGRA  2009    40                       185
# 7269  UTTAR PRADESH     AGRA  2010    26                       212
# 8056  UTTAR PRADESH     AGRA  2011    76                       328
# 8862  UTTAR PRADESH     AGRA  2012    58                       255
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
plt.figure(figsize=(15,10))
ax=sns.barplot(x="Rape",y="Year",data=tmp,orient='h')
ax.bar_label(ax.containers[0])
plt.title("STATE/UT Wise Total Cases of Importation of Girls in 2001-2012",fontsize=20)
# Out:
# Text(0.5, 1.0, 'STATE/UT Wise Total Cases of Importation of Girls in 2001-2012')

# %%
df.groupby(['Year']).sum()
# Out:
#        Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  32150                     29290         13702
# 2002  32746                     29012         13644
# 2003  31694                     26592         12416
# 2004  36466                     31156         14052
# 2005  36718                     31500         13574
# 2006  38696                     34828         15236
# 2007  41474                     40832         16186
# 2008  42934                     45878         16344
# 2009  42794                     51482         16766
# 2010  44344                     59590         16782
# 2011  48412                     71130         17236
# 2012  49846                     76524         16466
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                              68248
# 2002                                              67886
# 2003                                              65878
# ...

# %%
hh=df[df['DISTRICT']=="TOTAL"]
aa=hh.groupby(['DISTRICT']).sum()
aa.drop(['Year'],axis=1,inplace=True)
aa=aa.transpose()
display(aa)

aa.plot(kind='pie',autopct='%1.1f%%',subplots=True,figsize=(15,10))
plt.title("Cases in UTTAR PRADESH",fontsize=24)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()
# Out:
# DISTRICT                                             TOTAL
# Rape                                                232713
# Kidnapping and Abduction                            248257
# Dowry Deaths                                         89620
# Assault on women with intent to outrage her mod...  445621
# Insult to modesty of Women                          122367
# Cruelty by Husband or his Relatives                 859990
# Importation of Girls                                   891

# %%
def state_wise(df):
    state_wise=df[(df['DISTRICT']=="TOTAL")].copy()
    state_wise['Total_Cases']=state_wise['Rape']+state_wise['Kidnapping and Abduction']+state_wise['Dowry Deaths']+state_wise['Assault on women with intent to outrage her modesty']+state_wise['Insult to modesty of Women']+state_wise['Cruelty by Husband or his Relatives']+state_wise['Importation of Girls']
    state_wise.sort_values(by=['Year','STATE/UT'],inplace=True)
    return state_wise

aa=state_wise(df)
display(aa)
aa=aa.groupby(['DISTRICT']).sum()
display(aa)
aa.drop(['Year','Total_Cases'],axis=1,inplace=True)
display(aa)
aa=aa.transpose()
display(aa)
aa.plot(kind='pie',autopct='%1.1f%%',subplots=True,figsize=(15,10))
plt.title("Cases in UTTAR PRADESH",fontsize=24)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
# Out:
#                STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 691       A & N ISLANDS    TOTAL  2001     3                         2
# 28       ANDHRA PRADESH    TOTAL  2001   871                       765
# 42    ARUNACHAL PRADESH    TOTAL  2001    33                        55
# 70                ASSAM    TOTAL  2001   817                      1070
# 115               BIHAR    TOTAL  2001   888                       518
# ...                 ...      ...   ...   ...                       ...
# 8851         TAMIL NADU    TOTAL  2012   737                      1693
# 8861            TRIPURA    TOTAL  2012   229                       114
# 8938      UTTAR PRADESH    TOTAL  2012  1963                      7910
# 8952        UTTARAKHAND    TOTAL  2012   148                       256
# 8982        WEST BENGAL    TOTAL  2012  2046                      4168
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...
